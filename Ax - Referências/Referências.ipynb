# %% [markdown]
# <a href="https://colab.research.google.com/github/anderson-perez/IAC/blob/main/Ax%20-%20Refer%C3%AAncias/Refer%C3%AAncias.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Inteligência Artificial e Computacional

# %% [markdown]
# ## Segunda Parte da Disciplina
#
# # Informações:
#
# - Prof. Anderson Luiz Fernandes Perez
# - Contato: anderson.perez@ufsc.br | anderson.lfp@gmail.com
# - Os materiais da disciplina estarão disponíveis no github (https://github.com/anderson-perez/IAC.git)

# %% [markdown]
# # Referências sobre Inteligência Artificial

# %% [markdown]
# Este notebook reúne uma seleção de tutoriais, cursos e livros disponíveis gratuitamente na internet, com o objetivo de complementar os estudos e oferecer materiais de apoio para o aprofundamento dos conteúdos abordados.

# %% [markdown]
# ## Tutoriais

# %% [markdown]
# * [Fundamentos de IA](https://openai.com/pt-BR/academy/what-is-ai/)
# * [Deep Learning](https://www.deeplearningbook.org/)

# %% [markdown]
# ## Cursos e Minicursos

# %% [markdown]
# * [Elements of AI](https://course.elementsofai.com/pt)
# * [Fundação Bradesco - Escola Virtual - Curso de Inteligência Artificial](https://www.ev.org.br/areas-de-interesse/inteligencia-artificial)
# * [Microsoft Ignite - Build Foundational Generative AI Skills](https://learn.microsoft.com/en-us/training/paths/explore-microsoft-365-copilot-business-chat/)
# * [Google - Curso Intensivo de Machine Learning](https://developers.google.com/machine-learning/crash-course?hl=pt-br)

# %% [markdown]
# ## Livros

# %% [markdown]
# * [Dive into Deep Learning](https://pt.d2l.ai/)
# * [Deep Learning Book](https://www.deeplearningbook.com.br/)
# * [Mathematical Foundation of Reinforcement Learning](https://github.com/MathFoundationRL/Book-Mathematical-Foundation-of-Reinforcement-Learning)
# * [Learning Scientific Programming with Python (2nd edition)](https://scipython.com/books/book2/)
